# %%
import pm4py
import pandas

# %%
log = pm4py.read_xes("../data/intra.xes")
log.head()
# Out:
# parsing log, completed traces :: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████| 2000/2000 [00:00<00:00, 18448.46it/s]
#        event:id concept:name                  start_timestamp  \
# 0  evt_00000001            b        2020-01-01 00:00:00+00:00
# 1  evt_00000002            g 2020-01-01 00:44:37.676267+00:00
# 2  evt_00000003            h 2020-01-01 01:13:48.330860+00:00
# 3  evt_00000004            b 2020-01-01 00:41:07.153626+00:00
# 4  evt_00000005            g 2020-01-01 01:23:03.068921+00:00
#
#                     time:timestamp  event:duration_min org:resource  \
# 0 2020-01-01 00:23:55.486069+00:00           23.924768       res_08
# 1 2020-01-01 01:08:30.516156+00:00           23.880665       res_04
# 2 2020-01-01 01:34:40.648397+00:00           20.871959       res_04
# 3 2020-01-01 00:59:39.046357+00:00           18.531546       res_08
# 4 2020-01-01 01:51:32.222400+00:00           28.485891       res_03
#
# ...

# %%
# Step 1: create feature vector for each event

# %%
# Step 2: apply pca on feature vectors

# %%
# Step 3: train som

# %%
# Step 4: apply som

# %%
# Step 5: plot case trajectories

# %%
# Step 6: plot case state frequency distribution over time
