# %%
import pm4py
import pandas
import warnings

# %%
warnings.filterwarnings("ignore")
log = pm4py.read_xes("../data/intra.xes")
log[:5]
# Out:
# parsing log, completed traces :: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████| 2464/2464 [00:00<00:00, 16086.06it/s]
#        event:id concept:name                  start_timestamp  \
# 0  evt_00000001            b        2020-01-01 00:00:00+00:00
# 1  evt_00000002            g 2020-01-01 00:24:19.353292+00:00
# 2  evt_00000003            h 2020-01-01 01:33:28.051364+00:00
# 3  evt_00000004            b 2020-01-01 01:35:18.355889+00:00
# 4  evt_00000005            g 2020-01-01 02:17:58.411572+00:00
#
#                     time:timestamp  event:duration_min org:resource  \
# 0 2020-01-01 00:18:07.337264+00:00           18.122288       res_03
# 1 2020-01-01 01:12:03.738374+00:00           47.739751       res_06
# 2 2020-01-01 01:59:39.992804+00:00           26.199024       res_07
# 3 2020-01-01 01:58:00.780425+00:00           22.707076       res_03
# 4 2020-01-01 02:45:01.986501+00:00           27.059582       res_06
#
#   case:concept:name  case:amount case:region
# 0       case_000001      1108.44    region_1
# 1       case_000001      1108.44    region_1
# 2       case_000001      1108.44    region_1
# 3       case_000002       935.89    region_1
# 4       case_000002       935.89    region_1

# %%
df = log.sort_values(['case:concept:name', 'time:timestamp']).reset_index(drop=True)
#df[:5]

# %%
# Step 1: create feature vector for each event

# %%
# Step 2: apply pca on feature vectors

# %%
# Step 3: train som

# %%
# Step 4: apply som

# %%
# Step 5: plot case trajectories

# %%
# Step 6: plot case state frequency distribution over time
